# %%
#!pip install kafka-python
#!pip install faker
# currently using kafka-python-2.0.2, Faker-28.0.0
from kafka import KafkaProducer
from kafka import KafkaConsumer
import sys
import time
import random
import json
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import datetime as tm
from faker import Faker

# %%
#Kafka source details - this is for EDF Kafka Wire Protocol - so the broker is where Data Access Gateway is running and its port
server = "172.31.37.92:9092"
topic = "freshtopic"
print("BROKER: " + server)
print("TOPIC: " + topic)
# Out:
# BROKER: 172.31.37.92:9092
# TOPIC: freshtopic

# %%
# this API call will change based on the actual Kafka broker 
#PRODUCER
print("\n**Starting Producer**")
producer=KafkaProducer(bootstrap_servers=[server],
                        security_protocol='SASL_PLAINTEXT',
                        sasl_mechanism='PLAIN',
                        sasl_plain_username='mapr',
                        sasl_plain_password='mapr')
# Out:
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <connecting> [IPv4 ('172.31.37.92', 9092)]>: connecting to 172.31.37.92:9092 [('172.31.37.92', 9092) IPv4]
# Probing node bootstrap-0 broker version
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Sending username and password in the clear
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Authenticated as mapr via PLAIN
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Connection complete.
# **Starting Producer**
# Broker version identified as 2.4.0
# Set configuration api_version=(2, 4, 0) to skip auto check_version requests on startup
# <BrokerConnection node_id=0 host=ip-172-31-40-191.ap-southeast-2.compute.internal:9092 <connected> [IPv4 ('172.31.40.191', 9092)]>: Closing connection.

# %%
numMsgProduced = 0
fake = Faker()
for h in range(100):
    record = {
        "id": h+random.randint(1,100000),
        "name": fake.name(),
        "address": fake.address(),
        "amount": random.randint(1,1000000)
    }
    print(record)
    producer.send(topic, json.dumps(record).encode('utf-8'))
    numMsgProduced += 1
producer.flush()
print("Messages produced: " + str(numMsgProduced))
time.sleep(2)
# Out:
# {'id': 22082, 'name': 'Christine Rogers', 'address': 'Unit 2061 Box 5294\nDPO AP 38515', 'amount': 289376}
# {'id': 56413, 'name': 'Brittany Green', 'address': '26590 Clark Shoals\nChristopherfurt, MS 52759', 'amount': 519002}
# {'id': 22543, 'name': 'Ashley Johnson', 'address': 'USS Bullock\nFPO AA 72680', 'amount': 556919}
# {'id': 47289, 'name': 'Bobby Hebert', 'address': '237 Joseph Stravenue\nFloresstad, FM 24295', 'amount': 408452}
# {'id': 3541, 'name': 'Lauren Bell', 'address': '32655 Daniel Crossroad\nNew Brianshire, AL 67960', 'amount': 214789}
# {'id': 53413, 'name': 'Joshua Horton', 'address': '309 Darlene Extension\nNorth Davidmouth, DE 18896', 'amount': 680200}
# {'id': 46572, 'name': 'Anthony Smith', 'address': '9985 Cook Estate Apt. 703\nNorth Anaville, PR 33163', 'amount': 84565}
# {'id': 24917, 'name': 'April Freeman', 'address': '01037 Ashley Cove Apt. 831\nNew Jessicaborough, ND 01436', 'amount': 130820}
# {'id': 95676, 'name': 'Gabrielle Rasmussen', 'address': '2404 Barry Point\nNew Danielle, CT 22923', 'amount': 302742}
# {'id': 66164, 'name': 'Angela Miller', 'address': '3735 Eric Plain Apt. 938\nLake Lisa, MD 50808', 'amount': 170572}
# {'id': 76484, 'name': 'Gina Smith PhD', 'address': '03343 Nathan Tunnel\nSouth Patrick, ND 43795', 'amount': 983281}
# {'id': 40202, 'name': 'Jerry Marshall', 'address': '43462 Burch Cove\nCochranland, GA 39215', 'amount': 315007}
# {'id': 98535, 'name': 'Catherine Wilson', 'address': '47885 Daniel Turnpike Suite 407\nBakerborough, MN 33536', 'amount': 67949}
# {'id': 70529, 'name': 'Jessica Medina', 'address': '92515 Wright Trafficway Suite 792\nSouth Reneemouth, MO 20991', 'amount': 878838}
# {'id': 19082, 'name': 'Timothy Hunter', 'address': '0603 Sandra Mountain Suite 999\nPrestonhaven, WI 33964', 'amount': 345333}
# {'id': 79123, 'name': 'Mary Brown', 'address': 'USCGC Thompson\nFPO AP 16092', 'amount': 769153}
# {'id': 87580, 'name': 'Jacqueline Gordon', 'address': '6348 Allen Stream\nPattersonside, VA 51673', 'amount': 267477}
# {'id': 57296, 'name': 'Matthew Clark', 'address': '287 Taylor Locks\nNicoleshire, NH 58819', 'amount': 990737}
# {'id': 20330, 'name': 'Leslie Reed', 'address': '31364 Lauren Villages\nDiazberg, TN 46211', 'amount': 329112}
# {'id': 40069, 'name': 'Tammy Barnett', 'address': '2329 Brenda Ridges\nNorth Robertmouth, KS 42772', 'amount': 295467}
# {'id': 46834, 'name': 'Brett Garcia II', 'address': '09746 Olivia Roads\nSouth Ebony, PA 08191', 'amount': 196904}
# {'id': 77537, 'name': 'David Simmons', 'address': '40351 Preston Spring\nWest Amanda, RI 84816', 'amount': 366210}
# {'id': 53875, 'name': 'Katelyn Rubio', 'address': 'USS Lynn\nFPO AE 42122', 'amount': 146886}
# {'id': 80861, 'name': 'Lisa Herrera', 'address': '18404 Klein Loaf Apt. 146\nNorth Shannon, KS 23660', 'amount': 146314}
# {'id': 29141, 'name': 'Kimberly Aguirre', 'address': '398 Caroline Gardens\nPort Elizabethmouth, FM 41378', 'amount': 104798}
# {'id': 9384, 'name': 'Alex Jones', 'address': '6898 Kelly Ports Suite 881\nNew Antonio, RI 59774', 'amount': 207581}
# {'id': 81008, 'name': 'Kenneth Escobar', 'address': '138 Sloan Turnpike\nToddview, CA 98737', 'amount': 300015}
# {'id': 94198, 'name': 'Tamara Murphy', 'address': '124 Christopher Cliff\nSouth Michaelfort, CT 71302', 'amount': 611012}
# {'id': 97900, 'name': 'Jeffrey Wilson', 'address': '8387 Williams Plain Suite 438\nGillville, WA 82569', 'amount': 46001}
# {'id': 35397, 'name': 'Henry Farmer', 'address': '1902 Martinez Parks Suite 661\nSethton, MS 96137', 'amount': 56143}
# {'id': 6900, 'name': 'Angela Downs', 'address': '4122 Johnson Wells\nDanielleville, NH 76426', 'amount': 340027}
# {'id': 64044, 'name': 'Kimberly Glenn', 'address': '86999 Andersen Knolls Suite 040\nNew William, IL 54651', 'amount': 542548}
# {'id': 11013, 'name': 'Christy Byrd', 'address': '374 Jason Mission Suite 169\nCodybury, MS 57840', 'amount': 486504}
# {'id': 68485, 'name': 'Brian Bowman', 'address': '73018 Alyssa Club\nNew John, MO 68834', 'amount': 820484}
# {'id': 18975, 'name': 'Stephanie Garcia', 'address': '015 David Row\nPamelachester, MA 91687', 'amount': 485513}
# {'id': 59966, 'name': 'Aaron Hernandez', 'address': '80103 Martin Roads\nEast Ashley, CA 79544', 'amount': 197602}
# {'id': 8568, 'name': 'Kimberly Allen', 'address': '839 Johnny Mission Apt. 674\nNorth Kathleen, FL 63800', 'amount': 638793}
# {'id': 38366, 'name': 'Justin Perez', 'address': '260 Edward Green Suite 115\nReynoldstown, IA 40997', 'amount': 18836}
# {'id': 14697, 'name': 'Steven Scott', 'address': '217 Mark Forest\nFranciscomouth, IN 27813', 'amount': 739272}
# {'id': 22067, 'name': 'Chelsea Woods', 'address': '57988 Richmond Square Apt. 218\nWest Dakota, IL 96789', 'amount': 619081}
# {'id': 12026, 'name': 'Bobby Mcdonald', 'address': '01492 Compton Junctions\nEast Danielville, VT 99165', 'amount': 615261}
# {'id': 98504, 'name': 'Todd Rodriguez', 'address': '685 Michael Roads\nLopezborough, AZ 06656', 'amount': 425571}
# {'id': 3563, 'name': 'Bradley Salinas', 'address': '15770 Blanchard Pass Apt. 475\nValdezmouth, OK 32118', 'amount': 852999}
# {'id': 57625, 'name': 'Rachel Jensen', 'address': '65248 Fisher Plaza\nNathanielfort, DE 57364', 'amount': 99120}
# {'id': 13168, 'name': 'Richard Davis', 'address': '27990 Corey Terrace\nCarrieville, NM 05432', 'amount': 795222}
# {'id': 16236, 'name': 'Dylan Gonzales', 'address': '44840 Garcia Pass\nNorth Joshuachester, UT 52529', 'amount': 341220}
# {'id': 11483, 'name': 'Jaclyn Smith', 'address': '542 Olsen Lodge Suite 466\nSouth Kathleen, GU 43333', 'amount': 241690}
# {'id': 95814, 'name': 'Aaron Moore', 'address': '19226 Allen Track\nEast Kelly, WA 42955', 'amount': 369365}
# {'id': 47796, 'name': 'Wanda Meyer', 'address': '688 Bridges Port\nLake Tiffanyside, UT 17037', 'amount': 293967}
# {'id': 68810, 'name': 'Christine Cook', 'address': '51755 Dillon Springs Suite 917\nPort Katieville, WV 61857', 'amount': 680090}
# {'id': 50922, 'name': 'William Wilson', 'address': 'USS Webster\nFPO AP 83302', 'amount': 933701}
# {'id': 58020, 'name': 'Dr. Russell Stanley', 'address': 'Unit 3443 Box 5298\nDPO AE 19570', 'amount': 733274}
# {'id': 68591, 'name': 'Paul Woodard', 'address': '41918 Robert Throughway\nFlowersview, MS 49969', 'amount': 464687}
# {'id': 33470, 'name': 'Lauren Foster', 'address': '48918 Baxter Viaduct Apt. 888\nJoside, FM 99911', 'amount': 373322}
# {'id': 29554, 'name': 'Jennifer Michael', 'address': '4112 Jeffery Crossing\nSouth Lisa, VA 91872', 'amount': 908912}
# {'id': 67680, 'name': 'Carrie Chen', 'address': '194 Lisa Corners\nNew Lindamouth, NJ 95515', 'amount': 84967}
# {'id': 12874, 'name': 'Richard Palmer', 'address': '05542 Keith Extension Suite 713\nWest Patricia, LA 50168', 'amount': 757054}
# {'id': 70970, 'name': 'Susan Fry', 'address': '9086 Oconnell Street\nMichaelshire, WY 96456', 'amount': 333002}
# {'id': 29222, 'name': 'Mark Gutierrez', 'address': '1948 Jacqueline Village Apt. 817\nPort Shawn, WA 21383', 'amount': 701757}
# {'id': 98186, 'name': 'Mrs. Tammy Fields DDS', 'address': '222 John Garden Apt. 181\nJasonfurt, KY 57462', 'amount': 446098}
# {'id': 70543, 'name': 'Kristen Baker', 'address': '989 Jackson Shores Suite 380\nKeithside, KS 62541', 'amount': 927550}
# {'id': 1751, 'name': 'Meghan Cannon', 'address': '8195 Dennis Burg\nLeslieview, DE 81600', 'amount': 588485}
# {'id': 70870, 'name': 'Anthony Dorsey', 'address': '9865 Smith Forks\nTonyaland, IA 86736', 'amount': 886242}
# {'id': 64820, 'name': 'Erin Carrillo', 'address': '53226 April Roads Apt. 303\nSouth Douglasville, SD 49515', 'amount': 359975}
# {'id': 30265, 'name': 'Rachel Wagner', 'address': '85975 Kathryn Mall Suite 901\nWest Virginia, WA 17134', 'amount': 200258}
# {'id': 72945, 'name': 'Danny James', 'address': '1550 Kathleen Track Apt. 471\nLake Williamfort, AK 52699', 'amount': 471611}
# {'id': 84276, 'name': 'Kayla Brown', 'address': 'Unit 5699 Box 1748\nDPO AP 82585', 'amount': 22151}
# {'id': 28868, 'name': 'Charles Wright', 'address': '044 Bethany Glen\nNorth James, HI 30113', 'amount': 998378}
# {'id': 94217, 'name': 'William Coffey', 'address': '497 Jeffrey Shoal Apt. 073\nKramerborough, PA 37060', 'amount': 256460}
# {'id': 64889, 'name': 'Allen Richards', 'address': '333 Coleman Canyon\nMckayview, HI 39871', 'amount': 405816}
# {'id': 48899, 'name': 'Raymond Knox', 'address': '135 Regina Island\nLawsonton, WY 77147', 'amount': 310405}
# {'id': 43674, 'name': 'Rebekah Adkins', 'address': '625 Valerie Tunnel\nRichardtown, TX 76574', 'amount': 582352}
# {'id': 63351, 'name': 'Victor Olson', 'address': '2062 James Unions\nWest Julie, CA 16513', 'amount': 405072}
# {'id': 42373, 'name': 'Joseph Jones', 'address': '40740 John Lake Apt. 217\nWest Staceyton, AZ 88527', 'amount': 907748}
# {'id': 22038, 'name': 'Zachary Tate', 'address': '64305 Diana Route\nLake Richardborough, NY 88284', 'amount': 886073}
# {'id': 8474, 'name': 'Kimberly Smith', 'address': '296 Kim Ranch Apt. 560\nPort Joy, IN 63240', 'amount': 425710}
# {'id': 16876, 'name': 'Kayla Wilson', 'address': '587 Ferguson Pike Apt. 259\nEdwardside, MO 64251', 'amount': 55771}
# {'id': 44877, 'name': 'Joshua Velez', 'address': '9544 Patricia Heights Suite 596\nSmithfort, WV 96409', 'amount': 203086}
# {'id': 89096, 'name': 'Alice Edwards', 'address': '13968 Anthony Forks Suite 223\nJenniferview, WY 92893', 'amount': 167634}
# {'id': 50359, 'name': 'Sheila Barber', 'address': '209 Jasmine Island Suite 526\nPort Jaclynborough, WV 36707', 'amount': 402694}
# {'id': 11103, 'name': 'Cheyenne Conrad', 'address': '913 Brianna Terrace\nNew Mark, OH 76401', 'amount': 897727}
# {'id': 18745, 'name': 'Michael Lamb', 'address': '3547 Ford Mountains\nPort Frank, ID 95741', 'amount': 442001}
# {'id': 97300, 'name': 'Robert Barrett', 'address': '4003 Marquez Lane Apt. 040\nPeterstad, AZ 51354', 'amount': 905128}
# {'id': 62094, 'name': 'Belinda Gomez', 'address': '19463 Jones Flat\nWest Ianton, PW 58676', 'amount': 103196}
# {'id': 87345, 'name': 'Jonathan Holmes', 'address': '5116 Jennifer Forges\nTaraborough, FL 97920', 'amount': 445965}
# {'id': 76849, 'name': 'Kathy Walton', 'address': '4122 Crosby Crossing\nRandallview, DC 82361', 'amount': 480043}
# {'id': 48340, 'name': 'Kristine Vasquez', 'address': 'Unit 0219 Box 9856\nDPO AP 93801', 'amount': 383569}
# {'id': 48221, 'name': 'Edward Cook', 'address': '539 Salinas Harbors Suite 432\nJoelmouth, MT 41502', 'amount': 121202}
# {'id': 65764, 'name': 'Ricky Blair', 'address': '7571 Booth Ridges Suite 948\nPort Charles, NC 19402', 'amount': 208599}
# {'id': 26875, 'name': 'Brandon Parker', 'address': '415 Amy Forest\nVeronicaland, WV 23906', 'amount': 395227}
# {'id': 62780, 'name': 'Bryce Harris', 'address': '8581 Brandon Haven Apt. 037\nWatsonchester, KY 41728', 'amount': 110850}
# {'id': 84570, 'name': 'Robert Bailey', 'address': '446 Mark Village\nNorth Barbarastad, TX 53257', 'amount': 243189}
# {'id': 84773, 'name': 'Rachel Melendez', 'address': '44167 Green Brook Apt. 030\nChristinafort, HI 07567', 'amount': 749292}
# {'id': 96257, 'name': 'Daniel Santiago', 'address': '054 Allison Park Apt. 463\nNew Rachel, WV 73210', 'amount': 271380}
# {'id': 90519, 'name': 'William Rodriguez', 'address': '00569 Janet Trafficway\nPort Amystad, MH 12057', 'amount': 656094}
# {'id': 37999, 'name': 'Elizabeth Valentine', 'address': '590 Graham Wells Suite 183\nPort Natashaside, MH 39114', 'amount': 582998}
# {'id': 58487, 'name': 'Jacob Robinson', 'address': '897 Clayton Spring Suite 264\nDominguezchester, NH 11173', 'amount': 409292}
# {'id': 56789, 'name': 'David Weiss', 'address': '7737 Smith Loaf\nBrownburgh, IA 01641', 'amount': 440795}
# {'id': 61228, 'name': 'Renee Peters', 'address': '060 Holmes Gardens\nWest Chelsea, ME 89891', 'amount': 337224}
# {'id': 51543, 'name': 'Michael Newton MD', 'address': '29391 Peter Ways Suite 292\nAlexandershire, MS 07751', 'amount': 865560}
# Messages produced: 100

# %%
# this will keep track of records read and will ignore them in re-reading data
# Do NOT run this cell unless you want to go back to beginning for ingestion
consumer_offset = -1

# %%
#list of records received
fullrecords=[]
datarecords=[]

# %%
# CONSUMER
print("\n**Starting Consumer**")
consumer = KafkaConsumer(bootstrap_servers=[server],
                         auto_offset_reset='earliest',
                        security_protocol='SASL_PLAINTEXT',
                        sasl_mechanism='PLAIN',
                        sasl_plain_username='mapr',
                        sasl_plain_password='mapr')

consumer.subscribe(topic)
numMsgConsumed = 0

for _ in range(10):
    records = consumer.poll(timeout_ms=500)
    for topic_data, consumer_records in records.items():
        for consumer_record in consumer_records:
            if(consumer_record.offset > consumer_offset):
                print("Offset: " + str(consumer_record.offset) + "  Received message: " + consumer_record.value.decode('utf-8'))
                fullrecords.append(consumer_record)
                datarecords.append(json.loads(consumer_record.value.decode('utf-8')))
                consumer_offset = consumer_record.offset
                numMsgConsumed += 1
            else:
                print("Offset: " + str(consumer_record.offset) + " Already consumed")
print("New Messages consumed: " + str(numMsgConsumed))
# Out:
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <connecting> [IPv4 ('172.31.37.92', 9092)]>: connecting to 172.31.37.92:9092 [('172.31.37.92', 9092) IPv4]
# Probing node bootstrap-0 broker version
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Sending username and password in the clear
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Authenticated as mapr via PLAIN
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <authenticating> [IPv4 ('172.31.37.92', 9092)]>: Connection complete.
# **Starting Consumer**
# Broker version identified as 2.4.0
# Set configuration api_version=(2, 4, 0) to skip auto check_version requests on startup
# group_id is None: disabling auto-commit.
# Updating subscribed topics to: ['freshtopic']
# Updated partition assignment: [TopicPartition(topic='freshtopic', partition=0)]
# <BrokerConnection node_id=0 host=ip-172-31-40-191.ap-southeast-2.compute.internal:9092 <connecting> [IPv4 ('172.31.40.191', 9092)]>: connecting to ip-172-31-40-191.ap-southeast-2.compute.internal:9092 [('172.31.40.191', 9092) IPv4]
# <BrokerConnection node_id=0 host=ip-172-31-40-191.ap-southeast-2.compute.internal:9092 <authenticating> [IPv4 ('172.31.40.191', 9092)]>: Sending username and password in the clear
# <BrokerConnection node_id=0 host=ip-172-31-40-191.ap-southeast-2.compute.internal:9092 <authenticating> [IPv4 ('172.31.40.191', 9092)]>: Authenticated as mapr via PLAIN
# <BrokerConnection node_id=0 host=ip-172-31-40-191.ap-southeast-2.compute.internal:9092 <authenticating> [IPv4 ('172.31.40.191', 9092)]>: Connection complete.
# <BrokerConnection node_id=bootstrap-0 host=172.31.37.92:9092 <connected> [IPv4 ('172.31.37.92', 9092)]>: Closing connection.
# Offset: 0  Received message: {"id": 43946, "name": "Justin Guerra", "address": "954 Banks Forges\nHawkinsberg, MH 76341", "amount": 181384}
# Offset: 1  Received message: {"id": 85853, "name": "Katelyn Hernandez", "address": "5795 Mackenzie Fields Apt. 911\nLaurahaven, OH 08329", "amount": 37373}
# Offset: 2  Received message: {"id": 48532, "name": "Diane Harris PhD", "address": "2535 Schneider Rue Suite 835\nKruegershire, VI 71315", "amount": 629494}
# Offset: 3  Received message: {"id": 37061, "name": "Cassidy Skinner", "address": "536 Joshua Forge\nCarterfort, MI 55439", "amount": 187243}
# Offset: 4  Received message: {"id": 15468, "name": "Antonio Perez", "address": "USNV Jacobs\nFPO AE 48706", "amount": 733108}
# Offset: 5  Received message: {"id": 80154, "name": "Paula Monroe", "address": "40373 Justin Pines Apt. 251\nEricfort, IA 97181", "amount": 260877}
# Offset: 6  Received message: {"id": 64766, "name": "Kevin Byrd", "address": "9389 Rodney Crest Suite 361\nPort Lisaton, AZ 45944", "amount": 624182}
# Offset: 7  Received message: {"id": 89350, "name": "Kenneth Williams", "address": "975 Williams Mills Suite 987\nNew Aliciamouth, PR 49329", "amount": 964374}
# Offset: 8  Received message: {"id": 47982, "name": "Christopher Medina", "address": "7418 Peterson Road\nRobertshaven, WA 34106", "amount": 237558}
# Offset: 9  Received message: {"id": 47836, "name": "Heidi Hill", "address": "32545 James Pine\nKathrynview, LA 68441", "amount": 388659}
# Offset: 10  Received message: {"id": 72802, "name": "Robert Reed", "address": "PSC 8336, Box 0137\nAPO AE 93310", "amount": 642176}
# Offset: 11  Received message: {"id": 41372, "name": "Alexis Rhodes", "address": "5272 Kristine Locks Apt. 935\nSouth Adammouth, IL 29494", "amount": 488521}
# Offset: 12  Received message: {"id": 67863, "name": "Katie Parker", "address": "4115 Monroe Trail Apt. 582\nStewartchester, CT 04942", "amount": 898949}
# Offset: 13  Received message: {"id": 55560, "name": "Alyssa Frye", "address": "31915 Benjamin Street\nEast Melissa, LA 84457", "amount": 420575}
# Offset: 14  Received message: {"id": 74569, "name": "Donna Pope", "address": "98162 Dawn Locks Suite 178\nNorth James, NM 52579", "amount": 402592}
# Offset: 15  Received message: {"id": 23611, "name": "Lindsay Collins MD", "address": "74245 Benjamin Course Suite 525\nPhilipburgh, NM 06397", "amount": 529097}
# Offset: 16  Received message: {"id": 77853, "name": "Ronald Henderson", "address": "7044 Mendoza Mountain Apt. 890\nJeremymouth, FM 94662", "amount": 739493}
# Offset: 17  Received message: {"id": 35920, "name": "Emily Henderson", "address": "63900 Douglas Prairie Suite 264\nEast Derekbury, AR 01363", "amount": 10248}
# Offset: 18  Received message: {"id": 78810, "name": "Tiffany Villegas", "address": "2489 Boyd Ferry\nWest Troy, NH 20320", "amount": 150887}
# Offset: 19  Received message: {"id": 36196, "name": "Andrea Yu", "address": "9659 Brown Haven\nLake Allisonbury, ME 97704", "amount": 143346}
# Offset: 20  Received message: {"id": 37363, "name": "Brian Smith", "address": "040 Roy Corners Apt. 225\nJosephton, MT 75758", "amount": 746612}
# Offset: 21  Received message: {"id": 92555, "name": "Andrew Ibarra", "address": "180 Alexis Green\nNorth Karenmouth, MT 30669", "amount": 136139}
# Offset: 22  Received message: {"id": 2464, "name": "Juan Smith", "address": "32930 Charles Club Suite 358\nRandallhaven, VT 27826", "amount": 162394}
# Offset: 23  Received message: {"id": 5793, "name": "Benjamin Jackson", "address": "499 Smith Mews Apt. 348\nLake Allison, NC 10364", "amount": 60241}
# Offset: 24  Received message: {"id": 37754, "name": "Jack Henderson", "address": "005 Lopez Lodge Suite 584\nShermanview, AZ 95365", "amount": 380014}
# Offset: 25  Received message: {"id": 35278, "name": "Melissa Bender", "address": "91412 Guerrero Mills\nPort Melissa, AZ 75575", "amount": 189062}
# Offset: 26  Received message: {"id": 1749, "name": "Marvin Estrada Jr.", "address": "Unit 0711 Box 3501\nDPO AA 70559", "amount": 704709}
# Offset: 27  Received message: {"id": 57718, "name": "John Garcia", "address": "415 Perez Roads\nSouth Laura, AK 86029", "amount": 604621}
# Offset: 28  Received message: {"id": 41158, "name": "Jeffery Bean", "address": "2634 Wood Drive\nTaraview, MD 99845", "amount": 261304}
# Offset: 29  Received message: {"id": 42341, "name": "Eddie Sanders", "address": "Unit 9462 Box 5433\nDPO AA 91273", "amount": 162725}
# Offset: 30  Received message: {"id": 68435, "name": "Lori Le", "address": "689 Gibbs Mills\nWest Antoniofort, MH 99813", "amount": 113491}
# Offset: 31  Received message: {"id": 90490, "name": "Raymond Jackson", "address": "6818 Lloyd Road Apt. 312\nHeathermouth, ID 91498", "amount": 743359}
# Offset: 32  Received message: {"id": 87533, "name": "Travis Owens", "address": "6462 Andrew Extensions\nNielsenhaven, KY 94265", "amount": 150553}
# Offset: 33  Received message: {"id": 20240, "name": "Angela Petersen", "address": "641 Andrea Oval Suite 355\nNew Amyton, OH 24973", "amount": 62933}
# Offset: 34  Received message: {"id": 89205, "name": "Julia Hall", "address": "4751 Walton Loop\nNatalietown, PA 16740", "amount": 766458}
# Offset: 35  Received message: {"id": 90142, "name": "Eric Beck", "address": "302 Cook Row Suite 814\nDanieltown, DC 07291", "amount": 56248}
# Offset: 36  Received message: {"id": 11153, "name": "Shawn Alexander", "address": "7942 Mckenzie Street\nWest Breannaport, AL 72790", "amount": 50872}
# Offset: 37  Received message: {"id": 54875, "name": "Tony Kirby", "address": "526 Lindsay Center Suite 322\nWest Natashastad, AZ 34828", "amount": 336590}
# Offset: 38  Received message: {"id": 86662, "name": "Michelle Nielsen", "address": "3472 Stewart Meadow Apt. 703\nAntoniofurt, WV 85518", "amount": 679016}
# Offset: 39  Received message: {"id": 59683, "name": "Joshua Lester", "address": "33795 John Keys\nOrozcostad, PW 50860", "amount": 244310}
# Offset: 40  Received message: {"id": 74481, "name": "Jill Evans", "address": "8792 Hodge Harbors\nNelsontown, NY 57571", "amount": 243525}
# Offset: 41  Received message: {"id": 75193, "name": "Keith Day", "address": "USNV Terry\nFPO AE 56396", "amount": 361720}
# Offset: 42  Received message: {"id": 38485, "name": "Evan Meadows", "address": "0682 West Garden\nEast Holly, MS 96251", "amount": 213571}
# Offset: 43  Received message: {"id": 58642, "name": "Kimberly Santana", "address": "Unit 2434 Box 5096\nDPO AE 55634", "amount": 604555}
# Offset: 44  Received message: {"id": 99820, "name": "Marvin Owens", "address": "8561 Samantha Estates\nMorristown, DC 40099", "amount": 505213}
# Offset: 45  Received message: {"id": 41594, "name": "Johnathan Jimenez", "address": "364 Johnson Shores\nSheltonbury, MN 56929", "amount": 261652}
# Offset: 46  Received message: {"id": 12272, "name": "Scott Martinez", "address": "705 Barnett Vista Apt. 890\nEast Tinashire, ND 59194", "amount": 93010}
# Offset: 47  Received message: {"id": 87172, "name": "Felicia Peterson", "address": "93425 Brooks Harbor\nNorth Coreystad, RI 95209", "amount": 693540}
# Offset: 48  Received message: {"id": 44336, "name": "Samantha Schultz", "address": "67476 Murray Courts Apt. 240\nJenniferstad, WY 08246", "amount": 273131}
# Offset: 49  Received message: {"id": 38914, "name": "Shawn Mcgee", "address": "343 Burns Lake\nNorth Tarashire, NE 05101", "amount": 464167}
# Offset: 50  Received message: {"id": 29665, "name": "Mary Moore", "address": "94640 Amy Ville\nDeanstad, NJ 98382", "amount": 89637}
# Offset: 51  Received message: {"id": 49403, "name": "Michael Snyder", "address": "90701 Tonya Avenue\nEast Mathewland, AL 07758", "amount": 715272}
# Offset: 52  Received message: {"id": 30801, "name": "Bridget Grimes", "address": "31792 Larson Turnpike\nWest Lisamouth, VI 67692", "amount": 370805}
# Offset: 53  Received message: {"id": 28882, "name": "Claire Schneider", "address": "3937 Schaefer Curve\nCowanmouth, DC 84110", "amount": 193639}
# Offset: 54  Received message: {"id": 73217, "name": "Steven Serrano", "address": "5663 Sarah Mission\nLake Elizabeth, NC 71506", "amount": 485396}
# Offset: 55  Received message: {"id": 94419, "name": "Jessica Garcia DDS", "address": "609 Katherine Harbor\nLake Mariahmouth, DC 68946", "amount": 790834}
# Offset: 56  Received message: {"id": 86074, "name": "Harold Blackburn", "address": "755 Nelson Knolls Apt. 527\nNorth Connor, CA 65733", "amount": 114802}
# Offset: 57  Received message: {"id": 42462, "name": "Jackie Romero", "address": "137 Patterson Burg\nWest Michael, MO 31521", "amount": 568472}
# Offset: 58  Received message: {"id": 48307, "name": "Priscilla Black", "address": "80463 Paul Squares Apt. 431\nAndersonside, ME 79241", "amount": 685567}
# Offset: 59  Received message: {"id": 96591, "name": "Zachary Roach", "address": "94611 Peter Island\nNorth Sarahbury, AS 85700", "amount": 944691}
# Offset: 60  Received message: {"id": 50989, "name": "Mark Good", "address": "74700 Porter Pines Apt. 209\nHoffmantown, PA 31605", "amount": 81647}
# Offset: 61  Received message: {"id": 68855, "name": "Kimberly Case", "address": "94400 Horn Isle Apt. 402\nMindyberg, OK 09805", "amount": 427350}
# Offset: 62  Received message: {"id": 92330, "name": "Dennis Barry", "address": "4459 Elizabeth Forges\nNew Annaton, CT 64128", "amount": 198339}
# Offset: 63  Received message: {"id": 88369, "name": "Nancy Tyler", "address": "52893 Hernandez Drive\nPerezville, ND 15632", "amount": 63486}
# Offset: 64  Received message: {"id": 47373, "name": "Brian Ponce", "address": "4353 Marshall Mission Suite 627\nLoweshire, DC 62004", "amount": 776993}
# Offset: 65  Received message: {"id": 52702, "name": "Samuel Montgomery", "address": "62101 Robinson Court\nKathleentown, WA 28928", "amount": 591738}
# Offset: 66  Received message: {"id": 10534, "name": "Lauren Larson", "address": "88058 Jennings Gateway Apt. 187\nNorth Jonathanfurt, UT 24964", "amount": 243323}
# Offset: 67  Received message: {"id": 96197, "name": "Sharon Owens", "address": "USS Taylor\nFPO AE 72966", "amount": 679958}
# Offset: 68  Received message: {"id": 43320, "name": "Peter Holloway", "address": "Unit 6098 Box 1072\nDPO AA 21075", "amount": 660143}
# Offset: 69  Received message: {"id": 81396, "name": "Thomas Doyle", "address": "Unit 5691 Box 7621\nDPO AP 33584", "amount": 224432}
# Offset: 70  Received message: {"id": 43311, "name": "Claudia Lopez", "address": "73777 Franco Point Apt. 616\nHarrisfort, MD 40856", "amount": 523289}
# Offset: 71  Received message: {"id": 60635, "name": "Amy Robinson", "address": "USNS Davis\nFPO AP 41037", "amount": 716048}
# Offset: 72  Received message: {"id": 15427, "name": "Danielle Nelson", "address": "Unit 6438 Box 0367\nDPO AA 58572", "amount": 944866}
# Offset: 73  Received message: {"id": 85014, "name": "Deborah Kennedy", "address": "721 Anthony Ferry Suite 497\nDavidchester, MA 30799", "amount": 750021}
# Offset: 74  Received message: {"id": 37207, "name": "Bill Stone", "address": "PSC 0124, Box 5332\nAPO AP 26278", "amount": 535608}
# Offset: 75  Received message: {"id": 82797, "name": "Jason Wilson", "address": "1232 Elizabeth Bridge\nEast Joshua, WI 86903", "amount": 426916}
# Offset: 76  Received message: {"id": 11554, "name": "Samuel Jensen", "address": "059 Jennifer Brook\nPort Christopher, TN 11145", "amount": 839545}
# Offset: 77  Received message: {"id": 54076, "name": "Joshua Lee", "address": "3727 Charles Station\nAshleyfurt, OH 54283", "amount": 496521}
# Offset: 78  Received message: {"id": 83809, "name": "Christopher Day", "address": "0954 Barrera Mountain Suite 298\nBrianport, NM 06226", "amount": 476635}
# Offset: 79  Received message: {"id": 76805, "name": "Gabriella Rodriguez", "address": "3903 Ramirez Rest Suite 112\nMcclurehaven, LA 63703", "amount": 46848}
# Offset: 80  Received message: {"id": 40562, "name": "Colleen Stevens", "address": "385 Guerra Circles\nCurryfort, SC 65198", "amount": 309450}
# Offset: 81  Received message: {"id": 59064, "name": "Perry Jimenez", "address": "75769 Linda Roads Suite 673\nNew Martin, PA 20731", "amount": 120611}
# Offset: 82  Received message: {"id": 3723, "name": "Dominic Hamilton", "address": "7472 Saunders Unions\nNew Jason, FL 49569", "amount": 560143}
# Offset: 83  Received message: {"id": 52970, "name": "Catherine Neal", "address": "PSC 4871, Box 7428\nAPO AP 16120", "amount": 723468}
# Offset: 84  Received message: {"id": 98992, "name": "Jason Gillespie", "address": "3914 Price Curve\nPort Jodi, TN 58686", "amount": 592119}
# Offset: 85  Received message: {"id": 86076, "name": "Wanda Nelson", "address": "121 Spence Tunnel\nJoyton, CA 89680", "amount": 626072}
# Offset: 86  Received message: {"id": 59318, "name": "Jonathan Roman", "address": "255 Roy Corners\nNew John, SD 35926", "amount": 865710}
# Offset: 87  Received message: {"id": 828, "name": "Hannah Gray", "address": "3409 Solis Common Apt. 218\nAndersonborough, OH 57489", "amount": 801740}
# Offset: 88  Received message: {"id": 65537, "name": "Kathleen Williamson", "address": "9067 Williams Crossing\nNorth Kyle, KY 51729", "amount": 676060}
# Offset: 89  Received message: {"id": 7767, "name": "Christopher Johnson", "address": "3878 Potter Dam\nLake Lindafurt, MN 32909", "amount": 474758}
# Offset: 90  Received message: {"id": 79267, "name": "Jenny Simon", "address": "1220 Lester Bypass Suite 537\nAllenberg, CO 57811", "amount": 957711}
# Offset: 91  Received message: {"id": 17987, "name": "Kenneth Young", "address": "6555 Edwards Dam Apt. 122\nLake Patricia, NM 84197", "amount": 761459}
# Offset: 92  Received message: {"id": 17303, "name": "Laura James DDS", "address": "2084 Linda Circle Apt. 950\nWest Samuel, FM 47538", "amount": 955622}
# Offset: 93  Received message: {"id": 61667, "name": "David Alexander", "address": "0139 Rowe Views Suite 480\nYoungview, DC 49604", "amount": 125902}
# Offset: 94  Received message: {"id": 94179, "name": "Tara Atkinson", "address": "9434 Lowe Trail\nNorth Paulburgh, NV 66478", "amount": 768797}
# Offset: 95  Received message: {"id": 49189, "name": "Joseph Grimes", "address": "23424 Baker Mall Apt. 709\nEast Katie, LA 17678", "amount": 83234}
# Offset: 96  Received message: {"id": 10709, "name": "Ashley Owens", "address": "64908 Kelly View Suite 214\nLake Kimberlymouth, AZ 15546", "amount": 856140}
# Offset: 97  Received message: {"id": 60635, "name": "Caroline Stein", "address": "425 Jessica Plaza Apt. 441\nNew Kathy, WA 05833", "amount": 277483}
# Offset: 98  Received message: {"id": 39509, "name": "Brittany Lester", "address": "09668 Davis Trail\nCoopershire, MD 07143", "amount": 292613}
# Offset: 99  Received message: {"id": 39211, "name": "Kyle Weber", "address": "2037 Tanya Junction Apt. 762\nSouth Robert, MP 24065", "amount": 336002}
# Offset: 100  Received message: {"id": 3491, "name": "Rachel Strong", "address": "8213 Williams Station\nNew Linda, AK 98192", "amount": 378603}
# Offset: 101  Received message: {"id": 77653, "name": "John Lee", "address": "195 Trevor Walk Apt. 379\nJohnstad, PA 21476", "amount": 638444}
# Offset: 102  Received message: {"id": 1180, "name": "Courtney Lee", "address": "3240 James Centers Apt. 042\nLake Jessicaton, WY 52283", "amount": 856880}
# Offset: 103  Received message: {"id": 82550, "name": "Cheryl Cooper", "address": "PSC 7642, Box 9211\nAPO AP 49865", "amount": 208224}
# Offset: 104  Received message: {"id": 87306, "name": "Patricia Garcia", "address": "297 Glover Lane\nRamirezfort, UT 58700", "amount": 155780}
# Offset: 105  Received message: {"id": 99468, "name": "Lindsey Berry", "address": "13189 Elizabeth Plains\nNew William, ME 03219", "amount": 161282}
# Offset: 106  Received message: {"id": 52692, "name": "Heidi Peters", "address": "86154 Lee Roads\nEast Joseph, MO 82647", "amount": 846508}
# Offset: 107  Received message: {"id": 68966, "name": "Adriana Mccann", "address": "USCGC Bishop\nFPO AP 96475", "amount": 684732}
# Offset: 108  Received message: {"id": 60645, "name": "Jennifer Lewis", "address": "6756 Oneal Lane Apt. 621\nNorth Frank, AR 03905", "amount": 984644}
# Offset: 109  Received message: {"id": 82270, "name": "Albert Brown", "address": "03523 Denise Pines\nNorth Jessemouth, RI 80625", "amount": 992274}
# Offset: 110  Received message: {"id": 63371, "name": "Lindsey Edwards", "address": "542 Lowe Turnpike Apt. 936\nWest Sabrina, IN 87953", "amount": 560227}
# Offset: 111  Received message: {"id": 63482, "name": "Matthew Martinez", "address": "860 Simon Expressway\nRobertsfurt, ND 66683", "amount": 817116}
# Offset: 112  Received message: {"id": 5825, "name": "Amanda Smith", "address": "711 Donald Center\nNorth Marystad, ND 45504", "amount": 802997}
# Offset: 113  Received message: {"id": 38547, "name": "Andrew Wright", "address": "Unit 2162 Box 4386\nDPO AP 68195", "amount": 402969}
# Offset: 114  Received message: {"id": 15234, "name": "Margaret Obrien", "address": "6598 Cruz Valleys Apt. 848\nOdonnellstad, UT 31986", "amount": 926733}
# Offset: 115  Received message: {"id": 48428, "name": "Tyler Hayes", "address": "34485 Norman Estates Suite 186\nLake Nicolefurt, OK 48471", "amount": 408151}
# Offset: 116  Received message: {"id": 8519, "name": "Patricia Juarez", "address": "36659 Salazar Springs Apt. 512\nLyonston, DE 68563", "amount": 493574}
# Offset: 117  Received message: {"id": 54387, "name": "Keith Hill PhD", "address": "00282 Huffman Spurs\nAndersonbury, PR 23183", "amount": 497400}
# Offset: 118  Received message: {"id": 70545, "name": "John Brooks", "address": "936 Lacey Drive Suite 768\nWest Diana, CO 63328", "amount": 109005}
# Offset: 119  Received message: {"id": 40552, "name": "Peter Barker", "address": "USCGC King\nFPO AE 15375", "amount": 479782}
# Offset: 120  Received message: {"id": 87853, "name": "Shannon Anderson", "address": "77852 Laura Gardens Suite 086\nMelaniefurt, FL 92026", "amount": 934359}
# Offset: 121  Received message: {"id": 89180, "name": "Craig Elliott", "address": "63351 Harper Flats Suite 172\nMyerston, MP 27149", "amount": 911199}
# Offset: 122  Received message: {"id": 17762, "name": "Mason Reyes", "address": "Unit 2833 Box 9019\nDPO AA 50875", "amount": 695987}
# Offset: 123  Received message: {"id": 48891, "name": "John Hanna", "address": "692 Johnson Shoal\nLake Melissaburgh, SD 41057", "amount": 418201}
# Offset: 124  Received message: {"id": 81, "name": "Erin Nichols", "address": "Unit 2565 Box 3973\nDPO AP 56628", "amount": 544980}
# Offset: 125  Received message: {"id": 66585, "name": "Jennifer Walker", "address": "4775 Natalie View Apt. 930\nDavidborough, IA 42977", "amount": 704256}
# Offset: 126  Received message: {"id": 69479, "name": "Michael Sanchez", "address": "3647 Angela Inlet Apt. 275\nAyalaton, AR 85985", "amount": 515400}
# Offset: 127  Received message: {"id": 34863, "name": "Maria Delacruz", "address": "839 Bridges Oval\nNew Tiffanyport, PW 65350", "amount": 340306}
# Offset: 128  Received message: {"id": 59669, "name": "Matthew Clark", "address": "039 Mccarty Landing Suite 315\nLake Sarahhaven, AZ 21560", "amount": 82849}
# Offset: 129  Received message: {"id": 57686, "name": "Dana Williams", "address": "2148 Miller Points\nNew Eddiechester, NJ 02867", "amount": 802801}
# Offset: 130  Received message: {"id": 23698, "name": "Melanie Wheeler", "address": "200 Spencer Manor\nLake Paulaview, MN 05954", "amount": 232080}
# Offset: 131  Received message: {"id": 35244, "name": "Christian Hill", "address": "162 Schroeder Alley\nPort Stacy, MO 20316", "amount": 841913}
# Offset: 132  Received message: {"id": 86731, "name": "Ronnie Baird", "address": "2581 Moyer Manors\nNorth Stevenshire, SD 37909", "amount": 269856}
# Offset: 133  Received message: {"id": 10466, "name": "Charles Smith", "address": "Unit 8523 Box 2547\nDPO AA 98715", "amount": 703360}
# Offset: 134  Received message: {"id": 60018, "name": "Abigail Rojas", "address": "11415 Natasha Mount Apt. 882\nVazquezmouth, FM 52580", "amount": 92587}
# Offset: 135  Received message: {"id": 92205, "name": "Dawn Curtis", "address": "63636 Santos Summit\nReidfort, OH 14363", "amount": 513656}
# Offset: 136  Received message: {"id": 20692, "name": "Laura Hall DDS", "address": "PSC 3357, Box 8982\nAPO AA 64666", "amount": 824883}
# Offset: 137  Received message: {"id": 29479, "name": "Joshua Blair", "address": "136 Kevin Place Apt. 024\nJenniferchester, DC 43826", "amount": 368230}
# Offset: 138  Received message: {"id": 23215, "name": "Jeffery Stewart", "address": "2841 Mary Cliffs\nMontesstad, AS 53056", "amount": 267886}
# Offset: 139  Received message: {"id": 31203, "name": "Ryan Garcia", "address": "42351 Kaufman Village\nNew Ericfurt, MD 81800", "amount": 498074}
# Offset: 140  Received message: {"id": 1258, "name": "Frederick Martinez", "address": "39791 Brittany Glens Suite 589\nSouth Leroytown, IL 47060", "amount": 758108}
# Offset: 141  Received message: {"id": 78116, "name": "Terry Burnett", "address": "76231 Perez Tunnel\nRiosstad, ID 71560", "amount": 127520}
# Offset: 142  Received message: {"id": 31501, "name": "Michael Mitchell", "address": "066 Angela Springs Apt. 944\nJustinside, MD 61240", "amount": 189760}
# Offset: 143  Received message: {"id": 29139, "name": "Mark Morgan", "address": "PSC 0821, Box 9753\nAPO AP 33745", "amount": 353261}
# Offset: 144  Received message: {"id": 93151, "name": "Robert Sutton", "address": "Unit 4865 Box 5544\nDPO AA 00556", "amount": 429774}
# Offset: 145  Received message: {"id": 21310, "name": "Michael Hart", "address": "7083 Brown Forest Suite 905\nBateschester, NH 42022", "amount": 988565}
# Offset: 146  Received message: {"id": 24070, "name": "Tiffany Rios", "address": "67971 Antonio Cove\nAcostastad, NV 27877", "amount": 682111}
# Offset: 147  Received message: {"id": 88970, "name": "Kaitlyn Griffin", "address": "9126 Perry Hollow\nJoshuaview, NM 36413", "amount": 105040}
# Offset: 148  Received message: {"id": 45655, "name": "Robert Aguilar", "address": "33303 Bryan Knoll\nKnightton, NE 89050", "amount": 224014}
# Offset: 149  Received message: {"id": 61680, "name": "Heidi Harris", "address": "13089 Zavala Inlet Suite 716\nSouth Theresafurt, KY 16270", "amount": 113362}
# Offset: 150  Received message: {"id": 28354, "name": "John Zhang", "address": "769 Daniel Mall\nLake Leahburgh, FM 21812", "amount": 298058}
# Offset: 151  Received message: {"id": 63508, "name": "Daniel Johnson", "address": "0349 Hayes Center\nAustinborough, ME 74771", "amount": 612229}
# Offset: 152  Received message: {"id": 50269, "name": "Ernest Wolf", "address": "5527 Patricia Lakes\nPort Elizabethshire, MI 79638", "amount": 236029}
# Offset: 153  Received message: {"id": 80331, "name": "Gerald Rocha", "address": "262 Michael Falls Suite 943\nSkinnermouth, WI 74656", "amount": 829520}
# Offset: 154  Received message: {"id": 1914, "name": "Melinda Sims", "address": "10465 Butler Cape\nEast Kellystad, NY 66070", "amount": 969999}
# Offset: 155  Received message: {"id": 72478, "name": "Frank Daniels", "address": "438 Douglas Highway Apt. 288\nLake James, SD 44089", "amount": 965569}
# Offset: 156  Received message: {"id": 5989, "name": "Paige Avila", "address": "3292 Hutchinson Square\nDavidtown, MN 81444", "amount": 851588}
# Offset: 157  Received message: {"id": 41407, "name": "Sonya Williams", "address": "83937 Drake Falls\nMcculloughfort, IN 11362", "amount": 917477}
# Offset: 158  Received message: {"id": 47739, "name": "Emily Coffey", "address": "526 Pearson Ports\nMartinezland, MH 05297", "amount": 856119}
# Offset: 159  Received message: {"id": 27309, "name": "Karen Anderson", "address": "8155 Gary Row\nJamesfort, NV 26790", "amount": 952335}
# Offset: 160  Received message: {"id": 70132, "name": "Rose Wilson", "address": "528 Holly Course\nLake Lindsey, PW 17640", "amount": 751811}
# Offset: 161  Received message: {"id": 44420, "name": "Alyssa Jenkins", "address": "Unit 4224 Box 9299\nDPO AP 57430", "amount": 883182}
# Offset: 162  Received message: {"id": 9146, "name": "Donald Parker", "address": "19796 Nicole Ferry Suite 664\nEast Jeffrey, WV 68811", "amount": 258986}
# Offset: 163  Received message: {"id": 16446, "name": "Kelly Reyes", "address": "8540 Jonathan Creek\nWest Carol, VA 09505", "amount": 788653}
# Offset: 164  Received message: {"id": 97380, "name": "Evan Wu", "address": "74029 Martinez Oval Suite 017\nLake Gabriela, FM 50425", "amount": 115355}
# Offset: 165  Received message: {"id": 85727, "name": "Amber Thompson", "address": "594 Blake Way Suite 994\nThomasstad, AK 98936", "amount": 425539}
# Offset: 166  Received message: {"id": 98699, "name": "Caleb Alvarez", "address": "9372 Brown Pine Apt. 075\nEast Christian, AL 84177", "amount": 936405}
# Offset: 167  Received message: {"id": 82852, "name": "Mary Robinson", "address": "6873 Schultz Camp Suite 974\nLake Jacqueline, CT 41093", "amount": 315288}
# Offset: 168  Received message: {"id": 53526, "name": "Andrew Jenkins", "address": "5343 Connor Pike\nLindseyhaven, FL 83809", "amount": 719682}
# Offset: 169  Received message: {"id": 72981, "name": "James Perry", "address": "688 Foster Garden\nWest Jerry, NV 80670", "amount": 878901}
# Offset: 170  Received message: {"id": 72509, "name": "David Richardson", "address": "1874 John Knoll Suite 766\nMartinezville, FL 18515", "amount": 883240}
# Offset: 171  Received message: {"id": 93308, "name": "Jessica Jackson", "address": "23899 Karen Corners\nSmithfurt, UT 53324", "amount": 570850}
# Offset: 172  Received message: {"id": 63384, "name": "Keith Smith", "address": "5724 Stephens Village Suite 519\nEast Zacharyside, VA 77765", "amount": 393867}
# Offset: 173  Received message: {"id": 76195, "name": "Krista Chen", "address": "6114 Wright Flat Apt. 618\nLake Christinefurt, AZ 07334", "amount": 685656}
# Offset: 174  Received message: {"id": 12185, "name": "Crystal Long", "address": "Unit 8927 Box 1436\nDPO AP 31970", "amount": 735239}
# Offset: 175  Received message: {"id": 66445, "name": "Rhonda Jones", "address": "7935 Sanchez Green Suite 141\nNicolefort, CA 76015", "amount": 127380}
# Offset: 176  Received message: {"id": 79673, "name": "Cory Wade", "address": "632 Clark Pines\nSouth Jeffreychester, SD 37328", "amount": 91049}
# Offset: 177  Received message: {"id": 19194, "name": "James Johnson", "address": "0182 Madison Pines\nLake Samantha, AK 66120", "amount": 375156}
# Offset: 178  Received message: {"id": 63505, "name": "Jessica Kidd", "address": "6472 Cunningham Lights\nNorth Susan, TX 21050", "amount": 49689}
# Offset: 179  Received message: {"id": 27429, "name": "Joel Barrett", "address": "USNV Chavez\nFPO AE 27657", "amount": 137079}
# Offset: 180  Received message: {"id": 29564, "name": "Katelyn Ayers", "address": "063 Green Locks\nSheilahaven, GU 03665", "amount": 784103}
# Offset: 181  Received message: {"id": 34382, "name": "Paul Powell MD", "address": "82049 Waters Ridge\nPort Jasmine, AS 67443", "amount": 32815}
# Offset: 182  Received message: {"id": 86482, "name": "Erin Harris", "address": "40448 Moore Port Suite 058\nSouth Davidchester, TX 59446", "amount": 441866}
# Offset: 183  Received message: {"id": 78155, "name": "Shelia Taylor", "address": "289 Charles River\nPort Christinaview, IL 93982", "amount": 611999}
# Offset: 184  Received message: {"id": 33042, "name": "Amy Andrews", "address": "9689 Miller Grove Suite 535\nEast Kristahaven, UT 75952", "amount": 525765}
# Offset: 185  Received message: {"id": 4529, "name": "Eric Brown", "address": "USCGC Smith\nFPO AA 35073", "amount": 989800}
# Offset: 186  Received message: {"id": 37488, "name": "Jose Munoz", "address": "0664 Schneider Common Apt. 451\nVickibury, AZ 87235", "amount": 657612}
# Offset: 187  Received message: {"id": 85048, "name": "Lisa Bailey", "address": "483 Janice Squares\nChristopherberg, TX 28289", "amount": 797942}
# Offset: 188  Received message: {"id": 515, "name": "Rachel Dixon", "address": "20685 Judith Burgs Apt. 705\nNorth Darrenchester, WY 63956", "amount": 570370}
# Offset: 189  Received message: {"id": 65037, "name": "Melissa Barker", "address": "519 Richardson Motorway\nEricaport, VT 69185", "amount": 668782}
# Offset: 190  Received message: {"id": 61711, "name": "Theresa Martinez", "address": "PSC 9889, Box 1120\nAPO AE 10622", "amount": 719771}
# Offset: 191  Received message: {"id": 74956, "name": "Andrew Horn", "address": "06656 Harry Junctions Suite 727\nKlineville, MA 78515", "amount": 690811}
# Offset: 192  Received message: {"id": 2165, "name": "Sydney Casey", "address": "839 Gonzales Trail\nNew Kaylaview, AR 23211", "amount": 21627}
# Offset: 193  Received message: {"id": 56166, "name": "Gina Simmons", "address": "2130 Cobb Motorway\nLake Emilyhaven, MA 90454", "amount": 769279}
# Offset: 194  Received message: {"id": 27101, "name": "James Wells", "address": "PSC 4400, Box 1847\nAPO AA 48961", "amount": 157594}
# Offset: 195  Received message: {"id": 18906, "name": "Jenna Lee", "address": "PSC 9039, Box 6909\nAPO AA 39778", "amount": 785414}
# Offset: 196  Received message: {"id": 55131, "name": "Anna Elliott", "address": "06437 Alexander Throughway\nAshleyside, FM 91671", "amount": 881834}
# Offset: 197  Received message: {"id": 74569, "name": "Cynthia Chaney", "address": "4942 Monica Tunnel Apt. 468\nMillerburgh, CA 72021", "amount": 598994}
# Offset: 198  Received message: {"id": 6205, "name": "Anita Galvan", "address": "3878 Castillo Shore\nNancyborough, KS 22652", "amount": 596956}
# Offset: 199  Received message: {"id": 99001, "name": "Angela Hernandez", "address": "707 Angela Plaza\nNew Kennethberg, KY 39055", "amount": 495510}
# Offset: 200  Received message: {"id": 21516, "name": "Michael Jenkins", "address": "4861 Thompson Ville\nScotthaven, RI 62000", "amount": 927543}
# Offset: 201  Received message: {"id": 50361, "name": "Grant Jones", "address": "55198 Ryan Hollow Apt. 126\nChristopherside, WY 17491", "amount": 651164}
# Offset: 202  Received message: {"id": 26180, "name": "Cheryl Wright", "address": "822 Tony Valley Suite 383\nWest Kathryn, WY 05848", "amount": 605551}
# Offset: 203  Received message: {"id": 72826, "name": "Joshua Jackson", "address": "27517 Avery Junctions\nNew Ronaldberg, OK 93965", "amount": 721759}
# Offset: 204  Received message: {"id": 42705, "name": "Julia Brady MD", "address": "Unit 1940 Box 6473\nDPO AA 36765", "amount": 326673}
# Offset: 205  Received message: {"id": 64601, "name": "Nicole Singleton", "address": "USNV Christensen\nFPO AP 85873", "amount": 108635}
# Offset: 206  Received message: {"id": 24272, "name": "Mike Bean", "address": "1503 Nichols Forges Apt. 438\nKimport, AL 85251", "amount": 428280}
# Offset: 207  Received message: {"id": 28972, "name": "Mark Hunt", "address": "USNV Solomon\nFPO AE 73964", "amount": 749222}
# Offset: 208  Received message: {"id": 79418, "name": "Dr. Kirk Neal", "address": "3485 Johnson Park Apt. 567\nWest Annafort, WY 40717", "amount": 469887}
# Offset: 209  Received message: {"id": 95093, "name": "Stephanie Huang", "address": "4913 Anderson Circle\nJenniferborough, AL 22289", "amount": 396778}
# Offset: 210  Received message: {"id": 94928, "name": "Brent Beasley", "address": "67210 Howard Court\nLake Robertborough, AL 76103", "amount": 573412}
# Offset: 211  Received message: {"id": 44046, "name": "Patricia Ingram", "address": "157 Michael Curve\nGoodwinville, IL 46412", "amount": 848292}
# Offset: 212  Received message: {"id": 97180, "name": "Austin Moore", "address": "00296 Obrien Ports Apt. 677\nPort Melissaland, PW 21924", "amount": 323730}
# Offset: 213  Received message: {"id": 96438, "name": "Ruth Hernandez", "address": "PSC 3486, Box 3344\nAPO AE 50428", "amount": 61100}
# Offset: 214  Received message: {"id": 31541, "name": "Christopher Fowler", "address": "01555 Williams Mills\nRichardchester, AZ 46893", "amount": 994299}
# Offset: 215  Received message: {"id": 64620, "name": "Lynn Johnson", "address": "267 Damon Street\nWest Jamesborough, SC 28856", "amount": 371890}
# Offset: 216  Received message: {"id": 70557, "name": "Sarah Mejia", "address": "0592 Willis Expressway Apt. 265\nWest Antonioborough, MI 11070", "amount": 911508}
# Offset: 217  Received message: {"id": 48750, "name": "Ryan Garza", "address": "719 Jackson Mountain\nLake Michael, MO 74407", "amount": 222164}
# Offset: 218  Received message: {"id": 20599, "name": "Christian Hernandez", "address": "35514 Anderson Shores\nWardfort, ID 62792", "amount": 814364}
# Offset: 219  Received message: {"id": 5353, "name": "Michael Cook", "address": "USS Harris\nFPO AA 89050", "amount": 493330}
# Offset: 220  Received message: {"id": 76556, "name": "Mercedes Green", "address": "59451 Walker Run Apt. 183\nHarristown, MS 13119", "amount": 648281}
# Offset: 221  Received message: {"id": 58524, "name": "William Martin", "address": "1538 Gallegos Valleys Suite 421\nEast Bradley, NM 77256", "amount": 755042}
# Offset: 222  Received message: {"id": 22813, "name": "Joseph Kelly", "address": "7539 Joshua Club Apt. 389\nKathleenberg, LA 63497", "amount": 196351}
# Offset: 223  Received message: {"id": 61755, "name": "Melissa Johnson", "address": "1065 Perez Mount\nPort Deborah, NC 88446", "amount": 803291}
# Offset: 224  Received message: {"id": 17274, "name": "Karen Burke", "address": "4741 Little Lane Apt. 233\nMartinburgh, NY 54403", "amount": 436341}
# Offset: 225  Received message: {"id": 30865, "name": "Scott Khan", "address": "9248 Perez Estates Apt. 440\nNew Paul, AZ 75934", "amount": 816842}
# Offset: 226  Received message: {"id": 65379, "name": "Trevor Hampton", "address": "6767 Cook Motorway Suite 136\nMartinberg, OR 20053", "amount": 410639}
# Offset: 227  Received message: {"id": 76465, "name": "Adam Bell", "address": "2992 Patricia Well\nEast Stephanie, VA 33578", "amount": 433106}
# Offset: 228  Received message: {"id": 96835, "name": "Ashley Wang", "address": "9475 Valenzuela Shores Apt. 715\nMunozville, IA 15022", "amount": 382343}
# Offset: 229  Received message: {"id": 90967, "name": "Kimberly Jimenez", "address": "5390 Young Mews\nNorth Cynthiaberg, OR 77350", "amount": 620126}
# Offset: 230  Received message: {"id": 48656, "name": "Brenda White", "address": "77835 Swanson Haven\nWashingtonbury, DC 22207", "amount": 196282}
# Offset: 231  Received message: {"id": 39415, "name": "Jeffrey Webb", "address": "028 Victoria Port Suite 959\nSouth Williamport, NJ 35364", "amount": 70132}
# Offset: 232  Received message: {"id": 55604, "name": "Miss Tasha Werner", "address": "34106 Mccoy Walks\nDanielburgh, VT 06287", "amount": 7091}
# Offset: 233  Received message: {"id": 89482, "name": "Erica Brown", "address": "6732 Anna Circle Suite 188\nSouth Bradleyhaven, IN 92960", "amount": 934246}
# Offset: 234  Received message: {"id": 28029, "name": "Barbara Meza", "address": "424 Tony Village Suite 104\nPetersonview, WA 71058", "amount": 586991}
# Offset: 235  Received message: {"id": 76899, "name": "Courtney Taylor", "address": "68859 Don Squares\nEast Melissaview, PR 32882", "amount": 383613}
# Offset: 236  Received message: {"id": 27009, "name": "Deanna Jones", "address": "178 Anthony Springs\nNorth James, MD 53369", "amount": 804387}
# Offset: 237  Received message: {"id": 39348, "name": "Amanda Davis", "address": "3385 James Mission Suite 588\nEast Oliviabury, IL 90454", "amount": 699254}
# Offset: 238  Received message: {"id": 87595, "name": "Tiffany Clark", "address": "15452 Wright Falls Apt. 091\nEast Julia, PA 53266", "amount": 58183}
# Offset: 239  Received message: {"id": 26734, "name": "Robert Owens", "address": "80532 Rogers Land Apt. 357\nNorth Kristinemouth, AR 04429", "amount": 218053}
# Offset: 240  Received message: {"id": 39855, "name": "Joseph Long", "address": "83466 Mary Greens\nLake Ginaton, NC 29709", "amount": 302429}
# Offset: 241  Received message: {"id": 5128, "name": "Michaela Campbell", "address": "384 Louis Divide Apt. 532\nPort Davidshire, WI 79035", "amount": 902061}
# Offset: 242  Received message: {"id": 26352, "name": "Nancy Scott", "address": "68991 Tracy Island\nSouth Katrina, MA 32954", "amount": 566262}
# Offset: 243  Received message: {"id": 94754, "name": "Michael Crane", "address": "51137 Adkins Spurs\nSimmonsland, FM 83742", "amount": 3124}
# Offset: 244  Received message: {"id": 60977, "name": "Kevin Jackson", "address": "1162 Sherman Wells\nLake Brittney, VT 05351", "amount": 868238}
# Offset: 245  Received message: {"id": 74638, "name": "Jennifer Riley", "address": "655 Cunningham Garden Apt. 176\nEast Briannamouth, OH 77419", "amount": 993829}
# Offset: 246  Received message: {"id": 56669, "name": "Ronald Schroeder", "address": "901 Young Lock Suite 902\nGardnermouth, MA 56145", "amount": 757618}
# Offset: 247  Received message: {"id": 646, "name": "Brooke Palmer", "address": "55903 Trevor Ridge Apt. 410\nEast James, WA 60744", "amount": 360506}
# Offset: 248  Received message: {"id": 51695, "name": "Dorothy Stevenson", "address": "USNV Lyons\nFPO AP 36158", "amount": 370736}
# Offset: 249  Received message: {"id": 92503, "name": "Amy Holland", "address": "451 Garcia Lodge Apt. 949\nPort Jessicatown, PW 73894", "amount": 704724}
# Offset: 250  Received message: {"id": 89540, "name": "Kelly Shields", "address": "PSC 1134, Box 7373\nAPO AP 47774", "amount": 827328}
# Offset: 251  Received message: {"id": 80118, "name": "Curtis Pineda", "address": "Unit 6425 Box 2702\nDPO AE 55447", "amount": 436725}
# Offset: 252  Received message: {"id": 79986, "name": "Robert Tran", "address": "40176 Peter Curve Suite 963\nCookbury, CA 02635", "amount": 653396}
# Offset: 253  Received message: {"id": 25825, "name": "Alexander Brown", "address": "7241 Nichole Springs\nSouth Joshua, MH 88024", "amount": 91036}
# Offset: 254  Received message: {"id": 706, "name": "Lauren Newton", "address": "174 Jeffrey Ridge Apt. 806\nWilliamsonhaven, RI 18355", "amount": 564322}
# Offset: 255  Received message: {"id": 18962, "name": "Natalie Cooper", "address": "39136 Chang Bridge Suite 951\nWest Kaylamouth, MT 37534", "amount": 925014}
# Offset: 256  Received message: {"id": 26195, "name": "Michael Moore", "address": "562 Willis Spur Apt. 817\nEast Jasmine, DE 51768", "amount": 209305}
# Offset: 257  Received message: {"id": 73412, "name": "Kevin Salazar", "address": "PSC 4319, Box 0949\nAPO AP 26882", "amount": 823670}
# Offset: 258  Received message: {"id": 26643, "name": "Jerome Anderson", "address": "PSC 4393, Box 1712\nAPO AE 23887", "amount": 716076}
# Offset: 259  Received message: {"id": 13046, "name": "Scott Humphrey", "address": "USCGC Sanchez\nFPO AE 98295", "amount": 17972}
# Offset: 260  Received message: {"id": 52384, "name": "Michael Alexander", "address": "05546 Kristin Wells Suite 695\nEast Michaelmouth, AZ 43310", "amount": 403620}
# Offset: 261  Received message: {"id": 98350, "name": "Todd Weber", "address": "51450 Walton Ports Apt. 638\nJosephmouth, AR 69002", "amount": 379767}
# Offset: 262  Received message: {"id": 58852, "name": "Amy Miller", "address": "816 Ewing Trail\nJessicamouth, DC 47300", "amount": 968739}
# Offset: 263  Received message: {"id": 872, "name": "Taylor Martin", "address": "9254 Marie Bypass\nWest Kimberlymouth, LA 29267", "amount": 970609}
# Offset: 264  Received message: {"id": 50778, "name": "Gerald Smith", "address": "1484 Lisa Expressway\nAvilafort, AK 53989", "amount": 368478}
# Offset: 265  Received message: {"id": 12758, "name": "Matthew Woodward", "address": "PSC 7958, Box 3805\nAPO AA 46597", "amount": 478920}
# Offset: 266  Received message: {"id": 17448, "name": "Barbara Davis", "address": "3244 Chandler Corner\nSouth Katrinachester, CO 63425", "amount": 536313}
# Offset: 267  Received message: {"id": 15806, "name": "James Sullivan", "address": "91078 Jackson Trail Apt. 854\nNorth Jeffrey, MH 04017", "amount": 269014}
# Offset: 268  Received message: {"id": 27291, "name": "Kayla Jones", "address": "860 Cox Via\nEast Tanyashire, SD 69088", "amount": 152790}
# Offset: 269  Received message: {"id": 84367, "name": "Amy Brown", "address": "281 Bates Pass\nWest Moniqueview, PR 84402", "amount": 949641}
# Offset: 270  Received message: {"id": 26603, "name": "Becky Buchanan", "address": "274 Andrea Spurs\nWest Jenniferfort, MT 20521", "amount": 233060}
# Offset: 271  Received message: {"id": 2403, "name": "Anna Sandoval", "address": "5573 Cory Pass\nEast Jessicaland, CA 13227", "amount": 414562}
# Offset: 272  Received message: {"id": 59445, "name": "Jason Smith", "address": "PSC 7437, Box 5155\nAPO AP 80419", "amount": 285412}
# Offset: 273  Received message: {"id": 89302, "name": "Lee Bennett", "address": "4671 Butler Drives Suite 779\nGrayfort, ME 06728", "amount": 983017}
# Offset: 274  Received message: {"id": 668, "name": "Alexis Stevens", "address": "79571 Carter Glens\nAutumnside, ID 83869", "amount": 502729}
# Offset: 275  Received message: {"id": 35402, "name": "Ashley Estes", "address": "36992 Cochran Plaza Suite 692\nLake Destinyberg, AR 10717", "amount": 138375}
# Offset: 276  Received message: {"id": 59316, "name": "Susan Dougherty", "address": "7147 Nancy Gateway\nLake Nancyfort, PW 23701", "amount": 804506}
# Offset: 277  Received message: {"id": 51610, "name": "Kenneth Hernandez", "address": "15969 Dana Ford\nHunterland, FL 20113", "amount": 758888}
# Offset: 278  Received message: {"id": 3538, "name": "Joshua Brown", "address": "113 Ramirez Falls Suite 789\nPort Andrew, VA 54717", "amount": 115002}
# Offset: 279  Received message: {"id": 80698, "name": "Fernando Scott", "address": "USCGC Ortega\nFPO AA 09033", "amount": 961882}
# Offset: 280  Received message: {"id": 71143, "name": "Angela Larson", "address": "53988 Lawrence Radial Suite 509\nWilsonshire, CO 83427", "amount": 224535}
# Offset: 281  Received message: {"id": 44837, "name": "Evan Richard", "address": "97668 Thomas Hills Apt. 453\nLake Jamestown, OR 09823", "amount": 74034}
# Offset: 282  Received message: {"id": 75193, "name": "Mr. David Grant", "address": "1635 Raymond Bypass Apt. 521\nPort Kimberly, PA 09259", "amount": 223577}
# Offset: 283  Received message: {"id": 25418, "name": "Mark Davis", "address": "749 Mason Ridge\nNew Alecchester, SD 92396", "amount": 523982}
# Offset: 284  Received message: {"id": 97329, "name": "James Robles", "address": "8783 Jamie Well\nNorth Brian, NJ 86201", "amount": 144528}
# Offset: 285  Received message: {"id": 77562, "name": "Kristen Thompson", "address": "607 Miller Turnpike Apt. 200\nLake Jamieview, UT 17682", "amount": 295492}
# Offset: 286  Received message: {"id": 91162, "name": "Michelle Robinson", "address": "31854 Thompson Club\nLake Karl, FM 06502", "amount": 311949}
# Offset: 287  Received message: {"id": 65896, "name": "Luis Brown", "address": "31540 Johnson Roads\nWest Sethstad, RI 30014", "amount": 720225}
# Offset: 288  Received message: {"id": 47672, "name": "Ashley Smith", "address": "149 Phillip Street Suite 726\nLarsonport, DC 01613", "amount": 246745}
# Offset: 289  Received message: {"id": 68965, "name": "Dr. Shawn Fleming", "address": "00515 Jennifer Fields\nJoseton, VI 63032", "amount": 420613}
# Offset: 290  Received message: {"id": 49996, "name": "Carolyn Gordon", "address": "53689 Shaun Camp Suite 186\nLewisborough, OR 42045", "amount": 750840}
# Offset: 291  Received message: {"id": 2799, "name": "Allison Thomas", "address": "536 Kevin Divide\nStephanieville, AK 16879", "amount": 792460}
# Offset: 292  Received message: {"id": 44679, "name": "Taylor Edwards", "address": "38678 Matthew Viaduct Apt. 201\nNew Seanhaven, VT 41036", "amount": 771516}
# Offset: 293  Received message: {"id": 72608, "name": "Connie Mills", "address": "0613 Pace Locks Suite 436\nWilliamstown, RI 71314", "amount": 245040}
# Offset: 294  Received message: {"id": 64100, "name": "Jaime Cruz", "address": "98712 Daniel Groves\nNorth Linda, FM 63533", "amount": 727298}
# Offset: 295  Received message: {"id": 38392, "name": "Brandy Perez", "address": "3457 James Highway\nNew Kristyville, LA 82358", "amount": 82157}
# Offset: 296  Received message: {"id": 26080, "name": "Christopher Jackson", "address": "013 Watkins Via Suite 985\nTinamouth, MA 38304", "amount": 388745}
# Offset: 297  Received message: {"id": 66056, "name": "Kyle Moore", "address": "5727 Smith Overpass\nNew Timothybury, IL 55097", "amount": 246824}
# Offset: 298  Received message: {"id": 38625, "name": "Joshua Jones", "address": "24499 Garcia Rest Suite 232\nEast Jacob, NJ 66746", "amount": 2791}
# Offset: 299  Received message: {"id": 4444, "name": "Christopher Scott", "address": "7612 Megan Prairie\nWest Amy, RI 65388", "amount": 695204}
# Offset: 300  Received message: {"id": 6673, "name": "Oscar Martin", "address": "18765 Harrison Squares Apt. 467\nEast Sarastad, NV 72741", "amount": 968469}
# Offset: 301  Received message: {"id": 85957, "name": "Marvin Arnold", "address": "40410 Pope Ford\nJonburgh, OR 75112", "amount": 268675}
# Offset: 302  Received message: {"id": 53852, "name": "Robert Foster", "address": "789 James Cliff Suite 059\nLake Matthewfurt, AZ 51684", "amount": 845625}
# Offset: 303  Received message: {"id": 96453, "name": "Lisa Hampton", "address": "719 Bradley Prairie\nSouth Susanville, RI 08869", "amount": 469861}
# Offset: 304  Received message: {"id": 62190, "name": "Benjamin Anderson", "address": "141 Jessica Overpass\nRobinsonmouth, VA 56009", "amount": 125758}
# Offset: 305  Received message: {"id": 81711, "name": "Jamie Arroyo", "address": "5738 Jose Circle Apt. 683\nSouth Anthonyhaven, NY 69397", "amount": 499215}
# Offset: 306  Received message: {"id": 58653, "name": "Margaret Byrd", "address": "925 Campbell Brooks Suite 638\nLake David, IA 39859", "amount": 768949}
# Offset: 307  Received message: {"id": 74592, "name": "Terry Swanson", "address": "088 Warren Squares\nGatesland, MT 88374", "amount": 512678}
# Offset: 308  Received message: {"id": 48112, "name": "Felicia Welch", "address": "94951 Michael Garden Apt. 042\nJosephbury, GU 26209", "amount": 120506}
# Offset: 309  Received message: {"id": 52284, "name": "Evan Knight", "address": "6594 Dalton Canyon Apt. 267\nJohnsonbury, FL 02530", "amount": 48144}
# Offset: 310  Received message: {"id": 75730, "name": "Victoria Mcmahon", "address": "1867 Wendy Coves\nJakeberg, IA 91980", "amount": 221153}
# Offset: 311  Received message: {"id": 65927, "name": "Steven Richardson", "address": "47792 Hutchinson Tunnel Apt. 233\nEast Robinshire, AK 70613", "amount": 853363}
# Offset: 312  Received message: {"id": 60496, "name": "Richard Stout", "address": "USNS Johnson\nFPO AA 47347", "amount": 523255}
# Offset: 313  Received message: {"id": 16430, "name": "Monica Bates", "address": "34256 Susan Motorway\nNorth Juan, RI 27102", "amount": 648137}
# Offset: 314  Received message: {"id": 77801, "name": "Donna Nelson", "address": "924 Karen Corner Apt. 291\nNew Jacobmouth, AL 10992", "amount": 802061}
# Offset: 315  Received message: {"id": 81350, "name": "Amber Miller", "address": "58167 Parker Curve Apt. 057\nRuizburgh, VI 91762", "amount": 779687}
# Offset: 316  Received message: {"id": 13021, "name": "Brianna Garcia", "address": "3482 Ramirez Ferry\nSouth Jennifershire, MS 41563", "amount": 533453}
# Offset: 317  Received message: {"id": 74967, "name": "Terrance Parrish", "address": "5091 Williams Plain Suite 152\nAmberview, MT 81999", "amount": 446175}
# Offset: 318  Received message: {"id": 97329, "name": "Shannon Gutierrez", "address": "112 Thomas Ports\nElizabethburgh, FM 22504", "amount": 988394}
# Offset: 319  Received message: {"id": 97515, "name": "Jamie Carpenter", "address": "746 Stephanie Summit\nEast Martinshire, MD 04248", "amount": 846714}
# Offset: 320  Received message: {"id": 38263, "name": "Jennifer Cooper", "address": "03637 Alexander Alley\nNicolebury, LA 13164", "amount": 570024}
# Offset: 321  Received message: {"id": 44005, "name": "Lisa Garza", "address": "3790 Steven Parkways Apt. 582\nSouth Wendy, MH 22164", "amount": 520208}
# Offset: 322  Received message: {"id": 76987, "name": "Tony Dean", "address": "PSC 7707, Box 1729\nAPO AP 52458", "amount": 846277}
# Offset: 323  Received message: {"id": 44168, "name": "Andrew Flores", "address": "92490 Shelly Spring\nRoybury, GU 58634", "amount": 260961}
# Offset: 324  Received message: {"id": 92563, "name": "Matthew Ray", "address": "5027 Perez Loop Apt. 210\nWilliamsport, MD 08100", "amount": 103406}
# Offset: 325  Received message: {"id": 24670, "name": "Amanda Tucker", "address": "036 Michael Vista Apt. 569\nAngelaton, MS 02503", "amount": 532844}
# Offset: 326  Received message: {"id": 45363, "name": "Julie Moore", "address": "7637 Gonzalez Knolls Suite 234\nRobertsonfurt, MA 71487", "amount": 802602}
# Offset: 327  Received message: {"id": 26883, "name": "Paul Ward", "address": "104 Powell Island Apt. 511\nKarenfort, TN 52932", "amount": 169006}
# Offset: 328  Received message: {"id": 14384, "name": "Barbara Conner", "address": "9166 Kenneth Plains Apt. 338\nDanielleport, KY 05199", "amount": 105513}
# Offset: 329  Received message: {"id": 91162, "name": "Donna Nelson", "address": "1407 Matthew Well\nEast Terribury, VA 33435", "amount": 669967}
# Offset: 330  Received message: {"id": 83349, "name": "Russell Irwin", "address": "107 Hancock Square Apt. 589\nMelissaburgh, NC 92126", "amount": 465703}
# Offset: 331  Received message: {"id": 94852, "name": "Lauren Haas", "address": "13650 Wright Pass\nNorth Tammymouth, MP 92349", "amount": 64899}
# Offset: 332  Received message: {"id": 92279, "name": "April Chambers", "address": "56762 Cohen Freeway Suite 882\nWest Anthony, MH 81962", "amount": 354138}
# Offset: 333  Received message: {"id": 43406, "name": "Mrs. Sarah Turner", "address": "44507 Tammy Bridge Apt. 345\nEast Sarah, OH 67548", "amount": 199436}
# Offset: 334  Received message: {"id": 84101, "name": "Jessica White", "address": "158 Marshall Meadows Suite 433\nNew Jacobchester, NE 54947", "amount": 484410}
# Offset: 335  Received message: {"id": 34903, "name": "Sarah Johnson", "address": "72003 Kristin Wall\nWest Jordan, PA 17801", "amount": 780852}
# Offset: 336  Received message: {"id": 72012, "name": "Daniel Boyer", "address": "669 Stephen Orchard Apt. 624\nRobertburgh, FM 58677", "amount": 67609}
# Offset: 337  Received message: {"id": 33047, "name": "Ian Lamb", "address": "6513 Soto Mountains\nLake Jillside, FL 75011", "amount": 91276}
# Offset: 338  Received message: {"id": 30678, "name": "Jay Cox", "address": "Unit 8703 Box 8866\nDPO AE 35159", "amount": 371536}
# Offset: 339  Received message: {"id": 78134, "name": "Laura Montgomery", "address": "51623 Shawn Springs\nNorth Joseph, ID 96180", "amount": 265541}
# Offset: 340  Received message: {"id": 12201, "name": "Michelle Mills", "address": "45551 Gregory Shoals\nDelacruzchester, OK 87560", "amount": 207385}
# Offset: 341  Received message: {"id": 92028, "name": "Austin Young", "address": "750 Jennifer Radial\nLarryhaven, FL 71468", "amount": 222915}
# Offset: 342  Received message: {"id": 7677, "name": "Rachel Gomez", "address": "895 Lauren Ferry Apt. 272\nWest Sherrymouth, DC 54025", "amount": 34440}
# Offset: 343  Received message: {"id": 87537, "name": "Gregory Jarvis", "address": "9420 Jenna Manor\nMonroeborough, AK 30746", "amount": 107675}
# Offset: 344  Received message: {"id": 57906, "name": "Jorge Davies", "address": "3968 Anthony Mission Suite 626\nNorth Reneeberg, NC 22697", "amount": 150720}
# Offset: 345  Received message: {"id": 6571, "name": "Carol Wong", "address": "836 David Streets\nPhillipmouth, IA 01045", "amount": 842639}
# Offset: 346  Received message: {"id": 48883, "name": "Manuel Jones", "address": "47511 Stacey Avenue\nMartinton, MH 80796", "amount": 330392}
# Offset: 347  Received message: {"id": 59671, "name": "Steve Estrada", "address": "6922 Williams Square\nPort Susanport, CA 42203", "amount": 314524}
# Offset: 348  Received message: {"id": 89658, "name": "Karen Nielsen", "address": "5301 Roy Knoll Apt. 491\nEast Robert, AS 98635", "amount": 499892}
# Offset: 349  Received message: {"id": 8720, "name": "Kimberly Jones", "address": "885 Brian Shoals\nAmandahaven, CT 57927", "amount": 142281}
# Offset: 350  Received message: {"id": 21112, "name": "Justin Jackson", "address": "69630 Greene Drive\nHortonside, LA 83743", "amount": 6600}
# Offset: 351  Received message: {"id": 47273, "name": "Christine Barnes", "address": "67643 Jerry Branch\nEast Markview, TN 53499", "amount": 297199}
# Offset: 352  Received message: {"id": 11919, "name": "Sheila Harmon", "address": "90940 Donald Light Suite 137\nJohnborough, PW 50941", "amount": 18787}
# Offset: 353  Received message: {"id": 98508, "name": "Monica Smith", "address": "PSC 9116, Box 3303\nAPO AE 09091", "amount": 770319}
# Offset: 354  Received message: {"id": 18524, "name": "Alex Ramos", "address": "0204 Adkins Extension Suite 116\nSouth Christian, AR 90438", "amount": 555394}
# Offset: 355  Received message: {"id": 70165, "name": "Fred Wright", "address": "3696 Amy Key Apt. 003\nPetermouth, CO 06395", "amount": 155247}
# Offset: 356  Received message: {"id": 64528, "name": "Lisa Wilson", "address": "3937 Ramos Fork\nWest Melanie, NY 25136", "amount": 259137}
# Offset: 357  Received message: {"id": 66958, "name": "Beth Macias", "address": "5457 Russell Dale Suite 344\nPort Brittany, MP 34755", "amount": 63767}
# Offset: 358  Received message: {"id": 16120, "name": "Alexander Edwards", "address": "USS Brown\nFPO AE 31244", "amount": 476009}
# Offset: 359  Received message: {"id": 55783, "name": "Sarah Castillo", "address": "6170 Fields Lock\nDennisbury, WI 29165", "amount": 831888}
# Offset: 360  Received message: {"id": 15535, "name": "Renee Oconnor", "address": "312 Farmer Harbors Suite 866\nMartinezburgh, KY 61176", "amount": 593290}
# Offset: 361  Received message: {"id": 82647, "name": "Isabel Stone", "address": "2849 Gomez Shoal\nNew Rita, TX 04380", "amount": 672133}
# Offset: 362  Received message: {"id": 57309, "name": "Kenneth Calderon", "address": "26290 Williams Valleys Suite 932\nSouth Lauren, GU 64674", "amount": 720290}
# Offset: 363  Received message: {"id": 69304, "name": "Cindy Lynch", "address": "3771 Jackson Unions\nHudsonmouth, OH 52483", "amount": 996780}
# Offset: 364  Received message: {"id": 23204, "name": "John Murphy", "address": "Unit 9036 Box 8102\nDPO AA 80338", "amount": 78549}
# Offset: 365  Received message: {"id": 84530, "name": "Eric Wright", "address": "615 Ann Trail\nRobertmouth, AK 97333", "amount": 978140}
# Offset: 366  Received message: {"id": 44130, "name": "Patricia Gibbs", "address": "44357 Stephanie Path\nGriffithfurt, SD 97047", "amount": 690454}
# Offset: 367  Received message: {"id": 11597, "name": "Jeremy Briggs", "address": "USNS Payne\nFPO AE 73206", "amount": 238279}
# Offset: 368  Received message: {"id": 97271, "name": "Kimberly Thomas", "address": "59437 Wilcox Islands Suite 695\nKimberlyville, OH 16985", "amount": 265116}
# Offset: 369  Received message: {"id": 7001, "name": "Janet Koch", "address": "0370 David Freeway Apt. 309\nPort Stephenview, PA 60861", "amount": 711575}
# Offset: 370  Received message: {"id": 83531, "name": "Brianna Bradford", "address": "39317 Henry Falls Suite 634\nPatriciatown, NY 08351", "amount": 551827}
# Offset: 371  Received message: {"id": 23456, "name": "Mark Black", "address": "574 Mayo Estate\nLake Debbie, UT 08508", "amount": 30217}
# Offset: 372  Received message: {"id": 71949, "name": "Jamie Carter", "address": "USNV Hunter\nFPO AP 21677", "amount": 106690}
# Offset: 373  Received message: {"id": 3843, "name": "Heather Walker", "address": "467 Nolan Crossroad\nEast Lisaside, UT 14381", "amount": 290069}
# Offset: 374  Received message: {"id": 100058, "name": "Michael Colon", "address": "Unit 6635 Box 6349\nDPO AE 22938", "amount": 617379}
# Offset: 375  Received message: {"id": 89553, "name": "Victor Huffman", "address": "9079 Jason Mountain Suite 520\nLake Robert, VT 49066", "amount": 175832}
# Offset: 376  Received message: {"id": 82365, "name": "Ricky Simpson", "address": "3480 Tammy Mills Apt. 836\nBrownshire, PA 46303", "amount": 916614}
# Offset: 377  Received message: {"id": 22724, "name": "Edward Reeves", "address": "843 Sanchez Union\nPort Eric, IN 10277", "amount": 872264}
# Offset: 378  Received message: {"id": 6480, "name": "Jill Carroll", "address": "1081 Charles Neck\nJennaview, MO 88683", "amount": 498395}
# Offset: 379  Received message: {"id": 41328, "name": "Carla Richardson", "address": "Unit 2593 Box 4924\nDPO AE 10063", "amount": 768007}
# Offset: 380  Received message: {"id": 40568, "name": "Tanner Lee", "address": "98162 Martinez Crossroad\nPort Aaronborough, RI 35970", "amount": 466484}
# Offset: 381  Received message: {"id": 73644, "name": "Brenda Lee", "address": "717 Patterson Forge\nHayshaven, ME 98653", "amount": 424688}
# Offset: 382  Received message: {"id": 24118, "name": "Kim Johnson", "address": "8749 Reyes Islands\nSouth Georgeburgh, AK 87571", "amount": 891457}
# Offset: 383  Received message: {"id": 611, "name": "Dennis Perez", "address": "234 Pace Freeway Suite 204\nRussellburgh, PR 50673", "amount": 203736}
# Offset: 384  Received message: {"id": 93746, "name": "Holly Horton", "address": "256 Miranda Pike\nLake Dennisside, NE 48683", "amount": 348233}
# Offset: 385  Received message: {"id": 83816, "name": "Lindsay Johnston", "address": "298 Mora Green\nHowardfort, WI 28518", "amount": 948146}
# Offset: 386  Received message: {"id": 30084, "name": "Cynthia Bradley", "address": "917 Jeremy Passage\nNew Mikeside, IL 90060", "amount": 215258}
# Offset: 387  Received message: {"id": 35029, "name": "Preston Gould", "address": "39734 Wilson Hills Suite 831\nAllenfort, CA 94117", "amount": 674495}
# Offset: 388  Received message: {"id": 99636, "name": "Douglas Turner", "address": "406 Ashley Square Apt. 782\nMicheleburgh, ME 26759", "amount": 45434}
# Offset: 389  Received message: {"id": 28881, "name": "Jennifer Johnson", "address": "45350 Harrell Road\nRobertmouth, ME 59409", "amount": 933912}
# Offset: 390  Received message: {"id": 51953, "name": "Randy Rodriguez", "address": "13788 Ricardo Gardens Apt. 976\nLake Sylviamouth, TN 34402", "amount": 888936}
# Offset: 391  Received message: {"id": 34752, "name": "Renee Clark DDS", "address": "63223 Michael Roads\nRoseborough, NY 92460", "amount": 922208}
# Offset: 392  Received message: {"id": 3810, "name": "Rose Duran", "address": "340 Robert Plaza\nGutierrezview, MS 31901", "amount": 748118}
# Offset: 393  Received message: {"id": 87895, "name": "Lauren Joseph", "address": "3262 Jones Plain\nNew Emilyview, VA 99455", "amount": 914057}
# Offset: 394  Received message: {"id": 40451, "name": "Ricky Clark", "address": "9180 Amy Motorway\nNew Hannah, AL 82167", "amount": 946982}
# Offset: 395  Received message: {"id": 3594, "name": "Andrew Wong", "address": "5550 Villa Squares Suite 474\nGonzalezmouth, NH 38272", "amount": 729070}
# Offset: 396  Received message: {"id": 44632, "name": "Kiara Beltran", "address": "5186 Kimberly Brook Suite 656\nWest Lisa, CT 76314", "amount": 842544}
# Offset: 397  Received message: {"id": 39515, "name": "Joseph Lucas", "address": "06689 Diaz Camp\nFarleyland, DC 94561", "amount": 572432}
# Offset: 398  Received message: {"id": 67038, "name": "Justin White", "address": "71972 Kathleen Parkways\nNew Stephaniestad, MA 96242", "amount": 658807}
# Offset: 399  Received message: {"id": 84089, "name": "Steven King", "address": "845 Guzman Meadow\nNew Brandy, MD 88315", "amount": 418760}
# New Messages consumed: 400

# %%
# check offset is tracked correctly
consumer_offset
# Out:
# 399

# %%
#build pandas data frame from kafka consumer ingested records
optable = pa.Table.from_pandas(pd.DataFrame(datarecords))

# %%
uniquestr=tm.datetime.now().strftime("%Y-%m-%d-%H-%M")

# %%
pq.write_table(optable,"/mnt/shared/ingest1/source1/kafkaingest1"+uniquestr+".parquet")
